# %%
#project : predict Either the patient is Heart patient or not
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#load dataset
df=pd.read_csv("C:/Users/arohi/.jupyter/heart.csv")

# %%
#to show 5 records
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
#check null value
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
'''We have a data which classified if patients have heart disease or not 
according to features in it. We will try to use this data to create a model
which tries predict if a patient has this disease or not. 
We will use logistic regression (classification) algorithm.'''
# Out:
# 'We have a data which classified if patients have heart disease or not \naccording to features in it. We will try to use this data to create a model\nwhich tries predict if a patient has this disease or not. \nWe will use logistic regression (classification) algorithm.'

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#separate numerical type data and categorical type data 
#we create a list object num which hold all numeric type data from dataframe df
num = ["age","trestbps","chol","thalach","oldpeak"]
#we create a list object cat which hold all categorical type data from dataframe df
cat = ["sex","cp","fbs","exang","restecg","slope","ca","thal"]

# %%
#visualise distplot : create normal distributed curve , either data is 
#equally distribute or not  , displot always numerical type data
for col in num:
    sns.distplot(df[col])
    plt.show()

# %%
#Also check value of skewness
from scipy.stats import skew
for col in num:
    print(col)
    print(skew(df[col]))
    sns.distplot(df[col])
    plt.show()
# Out:
# age
# -0.2014596901125439
# trestbps
# 0.7102300604861443
# chol
# 1.1377326187082244
# thalach
# -0.5347455419075503
# oldpeak
# 1.2634255245891595

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#manually data analysis which numerical input imp to predict the target
for col in num:
    plt.figure()
    sns.scatterplot(data=df,x=col,y="target")
    plt.show()

# %%
#which features are important in categorical type data then use countplot()
#inbuilt function of seaborn library
for col in cat:
    plt.figure()
    sns.countplot(data=df,x="target",hue=col)#alwyas change hue means keep 
    #input features and x =target this is fixed
    plt.show()

# %%
#select Input and output variable from dataframe df
#means select Independent variable X and dependent variable Y
X=df.drop("target",axis=1)
Y=df["target"]

# %%
#train test split 
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
#create function
def create_model(model):
    model.fit(X_train,Y_train) #train the model
    y_pred = model.predict(X_test)#test the model
    print(classification_report(Y_test,y_pred))
    print("Confusion Matrix : ")
    print(confusion_matrix(Y_test,y_pred))
    return model

# %%
from sklearn.metrics import classification_report
#Confusion Matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # BaseLine Model : Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
#create the object of LogisticRegression class
lr=LogisticRegression()

# %%
#call function 
lr=create_model(lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77        41
#            1       0.80      0.86      0.83        50
#
#     accuracy                           0.80        91
#    macro avg       0.80      0.80      0.80        91
# weighted avg       0.80      0.80      0.80        91
#
# Confusion Matrix :
# [[30 11]
#  [ 7 43]]

# %%
'''
              Actual
             1   0
predicted 1  TP  FP  
          0  FN  TN
    
'''
#here my focus : FN means 7 patient : check recall
# Out:
# '\n              Actual\n             1   0\npredicted 1  TP  FP  \n          0  FN  TN\n    \n'

# %% [markdown]
# # Use DecisionTreeClassifier algorithm
# from sklearn.tree import DecisionTreeClassifier

# %%
# Use DecisionTreeClassifier algorithm 
from sklearn.tree import DecisionTreeClassifier

# %%
#create object of DecisionTreeClassifier class
dt=DecisionTreeClassifier() #bydefault gini index

# %%
#DecisionTreeClassifier : select important features to predcit the output

# %%
#call function
dt=create_model(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.76      0.71        41
#            1       0.78      0.70      0.74        50
#
#     accuracy                           0.73        91
#    macro avg       0.73      0.73      0.72        91
# weighted avg       0.73      0.73      0.73        91
#
# Confusion Matrix :
# [[31 10]
#  [15 35]]

# %%
#to show imp features 
dt.feature_importances_   # (show reduction)
# Out:
# array([0.09395307, 0.01713481, 0.31774899, 0.05925931, 0.06482656,
#        0.        , 0.0142537 , 0.05840245, 0.11895301, 0.08269578,
#        0.        , 0.12883356, 0.04393875])

# %%
X.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
#we visualize the tree
from sklearn import tree

# %%
features=X.columns

# %%
fig=plt.figure(figsize=(23,20))
_=tree.plot_tree(dt,feature_names=features,filled=True)

# %%
'''Pruning Technique  : to reduced overfitting situation'''
# Out:
# 'Pruning Technique  : to reduced overfitting situation'

# %%
'''1. First pruning tech. withy the help of max_depth()'''
# max_depth() not more than 8
# Out:
# '1. First pruning tech. withy the help of max_depth()'

# %%
#create the object of DecisionTreeClassifier
dt1=DecisionTreeClassifier(max_depth=8)  #set max_depth=8 means cut branches
#from tail

# %%
#call function
dt1=create_model(dt1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.71      0.68        41
#            1       0.74      0.70      0.72        50
#
#     accuracy                           0.70        91
#    macro avg       0.70      0.70      0.70        91
# weighted avg       0.71      0.70      0.70        91
#
# Confusion Matrix :
# [[29 12]
#  [15 35]]

# %%
Y_test.value_counts()
# Out:
# 1    50
# 0    41
# Name: target, dtype: int64

# %%
#to show imp features 
dt1.feature_importances_   # (show reduction)
# Out:
# array([0.10924487, 0.0172992 , 0.32079735, 0.08700977, 0.07983892,
#        0.        , 0.        , 0.02698398, 0.10570376, 0.08189019,
#        0.        , 0.1364653 , 0.03476665])

# %%
X.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
#Feature selection : - help to select imp features 
#feature_test user defined function
#first parameter score_func : criteria=fregression if anova test and chi2 
#if chi-2 test
#second parameter : k means how many imp features from dataset
#model : logistic or dt or svm means classification
def feature_test(criteria,count,model):
    test = SelectKBest(score_func=criteria,k=count)
    X_train_new = test.fit_transform(X_train,Y_train)
    X_test_new = test.transform(X_test)
    
    model.fit(X_train_new,Y_train)
    y_pred = model.predict(X_test_new)
    print(classification_report(Y_test,y_pred))
    
    print(test.get_support())#show imp features
    return model

# %%
X.shape
# Out:
# (303, 13)

# %%
from sklearn.feature_selection import chi2 #chi-2 test
from sklearn.feature_selection import f_regression #ANova test
from sklearn.feature_selection import SelectKBest

# %%
#Create object of LogisticRegression class
lr=LogisticRegression()
#call function
feature_test(f_regression,8,lr) #f_regression means =anova test and 8 : means
#no of imp features means k and lr means model train and test with logistic reg.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.78        41
#            1       0.80      0.88      0.84        50
#
#     accuracy                           0.81        91
#    macro avg       0.82      0.81      0.81        91
# weighted avg       0.82      0.81      0.81        91
#
# [False  True  True False False False False  True  True  True  True  True
#   True]
# LogisticRegression()

# %%
X.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
##Create object of LogisticRegression class
lr=LogisticRegression()
#call function
feature_test(chi2,4,lr) #chi-2 test
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74        41
#            1       0.77      0.86      0.81        50
#
#     accuracy                           0.78        91
#    macro avg       0.78      0.77      0.77        91
# weighted avg       0.78      0.78      0.78        91
#
# [False False  True False False False False  True False  True False  True
#  False]
# LogisticRegression()

# %%
#Use SVM : support vector machine : this is a classification supervised learning
#algo.
'''There are various kernel functions :
1. Linear Kernel (use linear separated data)
2. polynomial kernel (non-linearly)
3. radial basis kernel (non-linearly)'''
# Out:
# 'There are various kernel functions :\n1. Linear Kernel (use linear separated data)\n2. polynomial kernel (non-linearly)\n3. radial basis kernel (non-linearly)'

# %%
#1 . Linear Kernel (use linear separated data)

# %%
from sklearn.svm import LinearSVC

# %%
#create object of LinearSVC class
svc=LinearSVC(random_state=1)

# %%
#call function
create_model(svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.76        41
#            1       0.78      0.90      0.83        50
#
#     accuracy                           0.80        91
#    macro avg       0.81      0.79      0.80        91
# weighted avg       0.81      0.80      0.80        91
#
# Confusion Matrix :
# [[28 13]
#  [ 5 45]]
# LinearSVC(random_state=1)

# %%
#here recall is very good but we can more better
#means can be possible ,model is overfit 
#no error on training time but on testing time , some error occurs

# %%
#Soft margin means to reduced overfitting situation means some error add on
#training time 
#create object of LinearSVC class
svc1=LinearSVC(random_state=1,C=0.5) #here C is parameter which is used to
#add some error on training time

# %%
#again train the model and test again
#call function
create_model(svc1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.76        41
#            1       0.78      0.90      0.83        50
#
#     accuracy                           0.80        91
#    macro avg       0.81      0.79      0.80        91
# weighted avg       0.81      0.80      0.80        91
#
# Confusion Matrix :
# [[28 13]
#  [ 5 45]]
# LinearSVC(C=0.5, random_state=1)

# %%
svc1=LinearSVC(random_state=1,C=0.9)

# %%
create_model(svc1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.76        41
#            1       0.78      0.90      0.83        50
#
#     accuracy                           0.80        91
#    macro avg       0.81      0.79      0.80        91
# weighted avg       0.81      0.80      0.80        91
#
# Confusion Matrix :
# [[28 13]
#  [ 5 45]]
# LinearSVC(C=0.9, random_state=1)

# %%
#no any effect on recall if error increase or decrease means we conclude ,
#data is not a linearly separateable means non-linearly data 
#Then use polynomial Kernel function : It is used for Non-Linearly data
#In polynomial Kernal function, increase the dimension

# %%
#2. polynimial Kernel function 
from sklearn.svm import SVC

# %%
#SVC inbuilt class for non-linear data

# %%
#create object of SVC class(for polynomial)
poly_svc=SVC(random_state=1,kernel="poly")

# %%
#call function
create_model(poly_svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.54      0.56        41
#            1       0.65      0.70      0.67        50
#
#     accuracy                           0.63        91
#    macro avg       0.62      0.62      0.62        91
# weighted avg       0.62      0.63      0.62        91
#
# Confusion Matrix :
# [[22 19]
#  [15 35]]
# SVC(kernel='poly', random_state=1)

# %%
#3 . non-linear : radial basis kernel function

# %%
#create object of SVC class(for radial-basis)
radial_svc=SVC(random_state=1,kernel="rbf")

# %%
#call function
create_model(radial_svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.46      0.52        41
#            1       0.63      0.74      0.68        50
#
#     accuracy                           0.62        91
#    macro avg       0.61      0.60      0.60        91
# weighted avg       0.61      0.62      0.61        91
#
# Confusion Matrix :
# [[19 22]
#  [13 37]]
# SVC(random_state=1)

# %%
#in this domain : heart.csv , recall=0.98 in polynomial kernel function
#polynomial kernel function is best

# %%
from sklearn.decomposition import PCA

# %%
#Create object of PCA class
pc=PCA(n_components=None,random_state=1)  
#n_components  inbuilt parameters , here pass no. of pca but now given=None
#no pass any pca

# %%
X_train_pc=pc.fit_transform(X_train) #Training data 
#fit_transform() inbuilt method of PCA
X_test_pc=pc.transform(X_test) #TEsting data
#transform() inbuilt method of PCA

# %%
#to show strength means variance of each input column
explain_variance=pc.explained_variance_ratio_
print(explain_variance)
# Out:
# [6.99571453e-01 1.81708642e-01 9.78322631e-02 1.95289993e-02
#  3.70960604e-04 3.25238430e-04 2.66096534e-04 1.09870733e-04
#  8.49216582e-05 6.74827339e-05 5.28489188e-05 4.45692558e-05
#  3.66541727e-05]

# %%
X.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
#explained_variance_ratio_ inbuilt method of pca class

# %%
#Create object of PCA class
pc1=PCA(n_components=2,random_state=1)

# %%
X_train_pc1=pc1.fit_transform(X_train) #Training data 
#fit_transform() inbuilt method of PCA
X_test_pc1=pc1.transform(X_test) #TEsting data
#transform() inbuilt method of PCA

# %%
#apply classification algorithm because we predict customer_segment
#means customer belong which class either 1 or 2 or 3
#then use classification algo.  : logistic regression
from sklearn.linear_model import LogisticRegression

# %%
#Create object of LogisticRegression
lr=LogisticRegression() #lr user defined object of LogisticRegression

# %%
#Train the model then inbuilt function fit() of LogisticRegression class
lr.fit(X_train_pc1,Y_train)   #same as linearregression
# Out:
# LogisticRegression()

# %%
#find prediction means test the model
y_pred=lr.predict(X_test_pc1)

# %%
#To generate report means show all scores
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.66      0.64        41
#            1       0.70      0.66      0.68        50
#
#     accuracy                           0.66        91
#    macro avg       0.66      0.66      0.66        91
# weighted avg       0.66      0.66      0.66        91

# %%
#confusion matrix 
from sklearn.metrics import confusion_matrix

# %%
#Confusion matrix
confusion_matrix(Y_test,y_pred)
# Out:
# array([[27, 14],
#        [17, 33]], dtype=int64)

# %%
'''     actual  
               customer segment
               1   2    3
            1           
predicted   2   
            3
   #only one wrong prediction customer_segment=2
'''
# Out:
# '     actual  \n               customer segment\n               1   2    3\n            1           \npredicted   2   \n            3\n   #only one wrong prediction customer_segment=2\n'
